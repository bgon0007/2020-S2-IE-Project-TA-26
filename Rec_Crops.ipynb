# %% [markdown]
# ## Recommender System for Crops

# %% [markdown]
# In this notebook, I am developing a recommender system for crops based on soil ph using python for our project.Here, we are suggesting crops that are most similar to a particular crop.For instance, Potato is a crop which can be grown under different soil ph level, so we are trying to suggest crops that are similar to potato to different suburbs in Gippsland.

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %% [markdown]
# #### Reading required files

# %%
soil_df = pd.read_csv("soil_new.csv")
crop_df = pd.read_csv("crop_data.csv")

# %%
#viewing first few data for soil dataset
soil_df.head()
# Out:
#      Suburbs  Post Code                   soil_type  \
# 0  Aberfeldy       3825  Warragul with Silver Creek
# 1      Agnes       3962                  Strzelecki
# 2   Allambee       3823                    Yarragon
# 3    Almurta       3979                  Strzelecki
# 4   Anderson       3995               Leongatha Sth
#
#                                  geology  \
# 0  Tertiary Basalts & Tertiary sediments
# 1                   Cretaceous sediments
# 2           Pleistocene (late) sediments
# 3                   Cretaceous sediments
# 4                     Tertiary sediments
#
#                                  dominant soil  soil_ph
# 0      Brown and Yellow Kandosols or Dermosols      6.1
# 1      Acidic Grey, Yellow and Brown Dermosols      5.9
# 2                Brown Dermosols and Hydrosols      6.2
# 3      Acidic Grey, Yellow and Brown Dermosols      5.9
# 4  Humose-Acidic, Dermosolic, Redoxic HYDROSOL      5.0

# %%
#viewing first few rows of crops dataset
crop_df.head()
# Out:
#    soil_ph     crops
# 0      6.0  Cucumber
# 1      6.1  Cucumber
# 2      6.2  Cucumber
# 3      6.3  Cucumber
# 4      6.4  Cucumber

# %%
#Merging two datasets considering soil ph as the key
soil_df = pd.merge(soil_df, crop_df, on='soil_ph')

# %%
soil_df.head()
# Out:
#      Suburbs  Post Code                   soil_type  \
# 0  Aberfeldy       3825  Warragul with Silver Creek
# 1  Aberfeldy       3825  Warragul with Silver Creek
# 2  Aberfeldy       3825  Warragul with Silver Creek
# 3  Aberfeldy       3825  Warragul with Silver Creek
# 4  Aberfeldy       3825  Warragul with Silver Creek
#
#                                  geology  \
# 0  Tertiary Basalts & Tertiary sediments
# 1  Tertiary Basalts & Tertiary sediments
# 2  Tertiary Basalts & Tertiary sediments
# 3  Tertiary Basalts & Tertiary sediments
# 4  Tertiary Basalts & Tertiary sediments
#
#                              dominant soil  soil_ph     crops
# 0  Brown and Yellow Kandosols or Dermosols      6.1  Cucumber
# 1  Brown and Yellow Kandosols or Dermosols      6.1    Tomato
# 2  Brown and Yellow Kandosols or Dermosols      6.1    Potato
# 3  Brown and Yellow Kandosols or Dermosols      6.1  Eggplant
# 4  Brown and Yellow Kandosols or Dermosols      6.1      Corn

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# Let's create a dataframe with average soil ph and total soil ph with respect to crops.

# %%
soil_df.groupby('crops')['soil_ph'].mean().sort_values(ascending=False).head()   #mean of soil ph
# Out:
# crops
# Radish      7.000000
# Carrot      6.200000
# Zucchini    6.143750
# Cucumber    6.143750
# Tomato      6.116129
# Name: soil_ph, dtype: float64

# %%
soil_df.groupby('crops')['soil_ph'].count().sort_values(ascending=False).head() # total count
# Out:
# crops
# Potato      98
# Eggplant    98
# Corn        63
# Celery      63
# Oats        60
# Name: soil_ph, dtype: int64

# %% [markdown]
# Now create a dataframe with mean and total count of soil ph

# %%
soil_ph = pd.DataFrame(soil_df.groupby('crops')['soil_ph'].mean())

# %%
soil_ph
# Out:
#            soil_ph
# crops
# Carrot    6.200000
# Celery    6.004762
# Corn      6.004762
# Cucumber  6.143750
# Eggplant  5.847959
# Oats      4.768333
# Potato    5.847959
# Radish    7.000000
# Tomato    6.116129
# Zucchini  6.143750

# %%
soil_ph['number_soil_ph'] = pd.DataFrame(soil_df.groupby('crops')['soil_ph'].count())

# %%
soil_ph
# Out:
#            soil_ph  number_soil_ph
# crops
# Carrot    6.200000               9
# Celery    6.004762              63
# Corn      6.004762              63
# Cucumber  6.143750              32
# Eggplant  5.847959              98
# Oats      4.768333              60
# Potato    5.847959              98
# Radish    7.000000               1
# Tomato    6.116129              31
# Zucchini  6.143750              32

# %% [markdown]
# Now let's plot some histograms for the above dataframe

# %%
#histogram for total soil ph values
plt.figure(figsize=(10, 4))
soil_ph['number_soil_ph'].hist(bins=70)

# %%
#histogram for average soil ph values
plt.figure(figsize=(10, 4))
soil_ph['soil_ph'].hist(bins=50)

# %% [markdown]
# #### Recommending crops

# %% [markdown]
# Now let's create a matrix that has the suburbs on one axis and crops on another axis.Each cell will then consist of the values of soil ph and there will be a lot of NaN values as the most of the crops are not suitable for all of the suburbs.

# %%
#creating a table
crop_rec = soil_df.pivot_table(index = 'Suburbs', columns = 'crops', values = 'soil_ph')

# %%
crop_rec.head()
# Out:
# crops      Carrot  Celery  Corn  Cucumber  Eggplant  Oats  Potato  Radish  \
# Suburbs
# Aberfeldy     NaN     6.1   6.1       6.1       6.1   NaN     6.1     NaN
# Agnes         NaN     5.9   5.9       NaN       5.9   NaN     5.9     NaN
# Allambee      6.2     6.2   6.2       6.2       6.2   NaN     6.2     NaN
# Almurta       NaN     5.9   5.9       NaN       5.9   NaN     5.9     NaN
# Anderson      NaN     NaN   NaN       NaN       NaN   5.0     NaN     NaN
#
# crops      Tomato  Zucchini
# Suburbs
# Aberfeldy     6.1       6.1
# Agnes         NaN       NaN
# Allambee      6.2       6.2
# Almurta       NaN       NaN
# Anderson      NaN       NaN

# %%
crop_rec.reset_index(level=0, inplace=True)

# %%
crop_rec
# Out:
# crops         Suburbs  Carrot  Celery  Corn  Cucumber  Eggplant  Oats  Potato  \
# 0           Aberfeldy     NaN     6.1   6.1       6.1       6.1   NaN     6.1
# 1               Agnes     NaN     5.9   5.9       NaN       5.9   NaN     5.9
# 2            Allambee     6.2     6.2   6.2       6.2       6.2   NaN     6.2
# 3             Almurta     NaN     5.9   5.9       NaN       5.9   NaN     5.9
# 4            Anderson     NaN     NaN   NaN       NaN       NaN   5.0     NaN
# ..                ...     ...     ...   ...       ...       ...   ...     ...
# 152    Yallourn North     NaN     NaN   NaN       NaN       NaN   5.3     NaN
# 153           Yanakie     NaN     5.9   5.9       NaN       5.9   NaN     5.9
# 154          Yarragon     6.2     6.2   6.2       6.2       6.2   NaN     6.2
# 155            Yinnar     NaN     NaN   NaN       NaN       5.5   NaN     5.5
# 156      Yinnar South     NaN     NaN   NaN       NaN       5.5   NaN     5.5
#
# crops  Radish  Tomato  Zucchini
# 0         NaN     6.1       6.1
# 1         NaN     NaN       NaN
# 2         NaN     6.2       6.2
# 3         NaN     NaN       NaN
# 4         NaN     NaN       NaN
# ..        ...     ...       ...
# 152       NaN     NaN       NaN
# 153       NaN     NaN       NaN
# 154       NaN     6.2       6.2
# 155       NaN     NaN       NaN
# 156       NaN     NaN       NaN
#
# [157 rows x 11 columns]

# %%
#sorting the values of soil ph in descending order
soil_ph.sort_values('number_soil_ph', ascending=False)
# Out:
#            soil_ph  number_soil_ph
# crops
# Eggplant  5.847959              98
# Potato    5.847959              98
# Celery    6.004762              63
# Corn      6.004762              63
# Oats      4.768333              60
# Cucumber  6.143750              32
# Zucchini  6.143750              32
# Tomato    6.116129              31
# Carrot    6.200000               9
# Radish    7.000000               1

# %% [markdown]
# #### Finding correlation of potato with other crops

# %%
#Taking soil ph of each suburb for potato
potato_suburb_soil_ph = crop_rec['Potato']
potato_suburb_soil_ph.head()
# Out:
# 0    6.1
# 1    5.9
# 2    6.2
# 3    5.9
# 4    NaN
# Name: Potato, dtype: float64

# %%
#Uisng corrwith() method to get correlation of other crops with potato
similar_to_potato = crop_rec.corrwith(potato_suburb_soil_ph)

# %%
similar_to_potato
# Out:
# crops
# Carrot      NaN
# Celery      1.0
# Corn        1.0
# Cucumber    1.0
# Eggplant    1.0
# Oats        NaN
# Potato      1.0
# Radish      NaN
# Tomato      1.0
# Zucchini    1.0
# dtype: float64

# %%
#removing NaN values and using a DataFrame instead of a series
corr_potato = pd.DataFrame(similar_to_potato, columns=['Correlation'])
corr_potato.dropna(inplace = True)

# %%
corr_potato
# Out:
#           Correlation
# crops
# Celery            1.0
# Corn              1.0
# Cucumber          1.0
# Eggplant          1.0
# Potato            1.0
# Tomato            1.0
# Zucchini          1.0

# %%
#Add the corresponding soil ph count 
corr_potato = corr_potato.join(soil_ph['number_soil_ph'])

# %%
corr_potato
# Out:
#           Correlation  number_soil_ph
# crops
# Celery            1.0              63
# Corn              1.0              63
# Cucumber          1.0              32
# Eggplant          1.0              98
# Potato            1.0              98
# Tomato            1.0              31
# Zucchini          1.0              32

# %% [markdown]
# Now sort the values by filtering out the crops that have less than 10 count of soil ph.

# %%
corr_potato = corr_potato[corr_potato['number_soil_ph']>10].sort_values('Correlation', ascending = False)

# %%
#converting index of the above dataframe into list 
crops_new = corr_potato.index.values.tolist()

# %%
#function to convert list into string
def listToStringWithoutBrackets(crops_new):
    return str(crops_new).replace('[','').replace(']','')

# %%
crops_new = listToStringWithoutBrackets(crops_new)

# %%
crops_new
# Out:
# "'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomato', 'Cucumber', 'Zucchini'"

# %%
# print(crop_rec.loc[(crop_rec.Oats.notnull()), 'Suburbs'])

# %%
#Now add the obtained similar crops for potato
for index in crop_rec.index:
    crop_rec.loc[(crop_rec.Potato.notnull()), 'new'] = crops_new

# %% [markdown]
# There are less than 20 suburbs with ph value less than 5.5 and we have only one crop that can be grown in the ph value less than 5.5 (Oats) and there is no similar crops.Hence, we are adding the crop into the corresponding sububrs as shown below:

# %%
#For suburbs less than 5.5 ph value
for index in crop_rec.index:
    crop_rec.loc[(crop_rec.Oats.notnull()), 'new'] = 'Oats'

# %%
for index in crop_rec.index:
    crop_rec.loc[(crop_rec.Carrot.notnull()), 'new'] = crops_new + ", " + "Carrot"

# %%
crop_rec
# Out:
# crops         Suburbs  Carrot  Celery  Corn  Cucumber  Eggplant  Oats  Potato  \
# 0           Aberfeldy     NaN     6.1   6.1       6.1       6.1   NaN     6.1
# 1               Agnes     NaN     5.9   5.9       NaN       5.9   NaN     5.9
# 2            Allambee     6.2     6.2   6.2       6.2       6.2   NaN     6.2
# 3             Almurta     NaN     5.9   5.9       NaN       5.9   NaN     5.9
# 4            Anderson     NaN     NaN   NaN       NaN       NaN   5.0     NaN
# ..                ...     ...     ...   ...       ...       ...   ...     ...
# 152    Yallourn North     NaN     NaN   NaN       NaN       NaN   5.3     NaN
# 153           Yanakie     NaN     5.9   5.9       NaN       5.9   NaN     5.9
# 154          Yarragon     6.2     6.2   6.2       6.2       6.2   NaN     6.2
# 155            Yinnar     NaN     NaN   NaN       NaN       5.5   NaN     5.5
# 156      Yinnar South     NaN     NaN   NaN       NaN       5.5   NaN     5.5
#
# crops  Radish  Tomato  Zucchini  \
# 0         NaN     6.1       6.1
# 1         NaN     NaN       NaN
# 2         NaN     6.2       6.2
# 3         NaN     NaN       NaN
# 4         NaN     NaN       NaN
# ..        ...     ...       ...
# 152       NaN     NaN       NaN
# 153       NaN     NaN       NaN
# 154       NaN     6.2       6.2
# 155       NaN     NaN       NaN
# 156       NaN     NaN       NaN
#
# crops                                                new
# 0      'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 1      'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 2      'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 3      'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 4                                                   Oats
# ..                                                   ...
# 152                                                 Oats
# 153    'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 154    'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 155    'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 156    'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
#
# [157 rows x 12 columns]

# %%
#reading soil file
df = pd.read_csv("soil_new.csv")

# %%
df.head()
# Out:
#      Suburbs  Post Code                   soil_type  \
# 0  Aberfeldy       3825  Warragul with Silver Creek
# 1      Agnes       3962                  Strzelecki
# 2   Allambee       3823                    Yarragon
# 3    Almurta       3979                  Strzelecki
# 4   Anderson       3995               Leongatha Sth
#
#                                  geology  \
# 0  Tertiary Basalts & Tertiary sediments
# 1                   Cretaceous sediments
# 2           Pleistocene (late) sediments
# 3                   Cretaceous sediments
# 4                     Tertiary sediments
#
#                                  dominant soil  soil_ph
# 0      Brown and Yellow Kandosols or Dermosols      6.1
# 1      Acidic Grey, Yellow and Brown Dermosols      5.9
# 2                Brown Dermosols and Hydrosols      6.2
# 3      Acidic Grey, Yellow and Brown Dermosols      5.9
# 4  Humose-Acidic, Dermosolic, Redoxic HYDROSOL      5.0

# %%
#creating a dataframe to store the recommended crops and other details
recommended_crops = pd.DataFrame(columns=['Suburbs','PostCode', 'Soil Type', 'Dominant Soils', 'Soil PH', 'Crops'])

# %%
recommended_crops
# Out:
# Empty DataFrame
# Columns: [Suburbs, PostCode, Soil Type, Dominant Soils, Soil PH, Crops]
# Index: []

# %%
#Adding similar values into the recommended dataframe
recommended_crops['Suburbs'] = df['Suburbs']
recommended_crops['PostCode'] = df['Post Code']
recommended_crops['Soil Type'] = df['soil_type']
recommended_crops['Dominant Soils'] = df['dominant soil']
recommended_crops['Soil PH'] = df['soil_ph']

# %%
recommended_crops.head()
# Out:
#      Suburbs  PostCode                   Soil Type  \
# 0  Aberfeldy      3825  Warragul with Silver Creek
# 1      Agnes      3962                  Strzelecki
# 2   Allambee      3823                    Yarragon
# 3    Almurta      3979                  Strzelecki
# 4   Anderson      3995               Leongatha Sth
#
#                                 Dominant Soils  Soil PH Crops
# 0      Brown and Yellow Kandosols or Dermosols      6.1   NaN
# 1      Acidic Grey, Yellow and Brown Dermosols      5.9   NaN
# 2                Brown Dermosols and Hydrosols      6.2   NaN
# 3      Acidic Grey, Yellow and Brown Dermosols      5.9   NaN
# 4  Humose-Acidic, Dermosolic, Redoxic HYDROSOL      5.0   NaN

# %%
#merging two datasets to obtain the crops that are correlated to each other
recommended_crops = pd.merge(recommended_crops, crop_rec, on="Suburbs")

# %%
recommended_crops
# Out:
#             Suburbs  PostCode                   Soil Type  \
# 0         Aberfeldy      3825  Warragul with Silver Creek
# 1             Agnes      3962                  Strzelecki
# 2          Allambee      3823                    Yarragon
# 3           Almurta      3979                  Strzelecki
# 4          Anderson      3995               Leongatha Sth
# ..              ...       ...                         ...
# 153  Yallourn North      3825                   Inverloch
# 154         Yanakie      3960                  Strzelecki
# 155        Yarragon      3823                    Yarragon
# 156          Yinnar      3869       Boolarra with Morwell
# 157    Yinnar South      3869       Boolarra with Morwell
#
#                                         Dominant Soils  Soil PH Crops  Carrot  \
# 0              Brown and Yellow Kandosols or Dermosols      6.1   NaN     NaN
# 1              Acidic Grey, Yellow and Brown Dermosols      5.9   NaN     NaN
# 2                        Brown Dermosols and Hydrosols      6.2   NaN     6.2
# 3              Acidic Grey, Yellow and Brown Dermosols      5.9   NaN     NaN
# 4          Humose-Acidic, Dermosolic, Redoxic HYDROSOL      5.0   NaN     NaN
# ..                                                 ...      ...   ...     ...
# 153        Humose-Acidic, Dermosolic, Redoxic HYDROSOL      5.3   NaN     NaN
# 154            Acidic Grey, Yellow and Brown Dermosols      5.9   NaN     NaN
# 155                      Brown Dermosols and Hydrosols      6.2   NaN     6.2
# 156  Acidic Yellow and Grey Dermosols & Kurosols/Ac...      5.5   NaN     NaN
# 157  Acidic Yellow and Grey Dermosols & Kurosols/Ac...      5.5   NaN     NaN
#
#      Celery  Corn  Cucumber  Eggplant  Oats  Potato  Radish  Tomato  Zucchini  \
# 0       6.1   6.1       6.1       6.1   NaN     6.1     NaN     6.1       6.1
# 1       5.9   5.9       NaN       5.9   NaN     5.9     NaN     NaN       NaN
# 2       6.2   6.2       6.2       6.2   NaN     6.2     NaN     6.2       6.2
# 3       5.9   5.9       NaN       5.9   NaN     5.9     NaN     NaN       NaN
# 4       NaN   NaN       NaN       NaN   5.0     NaN     NaN     NaN       NaN
# ..      ...   ...       ...       ...   ...     ...     ...     ...       ...
# 153     NaN   NaN       NaN       NaN   5.3     NaN     NaN     NaN       NaN
# 154     5.9   5.9       NaN       5.9   NaN     5.9     NaN     NaN       NaN
# 155     6.2   6.2       6.2       6.2   NaN     6.2     NaN     6.2       6.2
# 156     NaN   NaN       NaN       5.5   NaN     5.5     NaN     NaN       NaN
# 157     NaN   NaN       NaN       5.5   NaN     5.5     NaN     NaN       NaN
#
#                                                    new
# 0    'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 1    'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 2    'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 3    'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 4                                                 Oats
# ..                                                 ...
# 153                                               Oats
# 154  'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 155  'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 156  'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 157  'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
#
# [158 rows x 17 columns]

# %% [markdown]
# #### Dropping unwanted columns

# %%
recommended_crops=recommended_crops.drop(['Carrot', 'Carrot','Corn', 'Celery', 'Cucumber', 'Eggplant', 'Oats', 'Potato', 'Tomato', 'Zucchini', 'Radish'], axis = 1)

# %%
recommended_crops['Crops'] = recommended_crops['new']

# %%
recommended_crops =recommended_crops.drop(['new'], axis = 1)

# %%
recommended_crops.head()
# Out:
#      Suburbs  PostCode                   Soil Type  \
# 0  Aberfeldy      3825  Warragul with Silver Creek
# 1      Agnes      3962                  Strzelecki
# 2   Allambee      3823                    Yarragon
# 3    Almurta      3979                  Strzelecki
# 4   Anderson      3995               Leongatha Sth
#
#                                 Dominant Soils  Soil PH  \
# 0      Brown and Yellow Kandosols or Dermosols      6.1
# 1      Acidic Grey, Yellow and Brown Dermosols      5.9
# 2                Brown Dermosols and Hydrosols      6.2
# 3      Acidic Grey, Yellow and Brown Dermosols      5.9
# 4  Humose-Acidic, Dermosolic, Redoxic HYDROSOL      5.0
#
#                                                Crops
# 0  'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 1  'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 2  'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 3  'Celery', 'Corn', 'Eggplant', 'Potato', 'Tomat...
# 4                                               Oats

# %% [markdown]
# #### Writing into a csv file

# %%
recommended_crops.to_csv('recommendation.csv', index=False)
